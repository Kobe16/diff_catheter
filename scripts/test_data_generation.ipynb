# %%
import os
import numpy as np

import camera_settings
import path_settings
# Out:
# Camera Intrinsics:
# [[883.00220751   0.         320.        ]
#  [  0.         883.00220751 240.        ]
#  [  0.           0.           1.        ]]
# Camera Extrinsics:
# [[-1.00000000e+00 -1.22464680e-16  1.49975978e-32  0.00000000e+00]
#  [-1.22464680e-16  1.00000000e+00 -1.22464680e-16  0.00000000e+00]
#  [ 0.00000000e+00 -1.22464680e-16 -1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]

# %%
import random
import numpy as np
import transforms

from cc_catheter import CCCatheter


class DataGeneration:

    def __init__(self, n_data, p_0, r, l, s_list, save_path):
        """
        Args:
            n_data (int): number of data points (variations of parameters as test cases) to generate
            p_0 ((3,) numpy array): start point of catheter
            r (float): cross section radius of catheter
            l (float): length of catheter
            s_list (list of s values): s values of points on the constant curvature curve except for
                the start point. s values are floats from 0 to 1 inclusive
            save_path (path string to npy file): path to save the generated data
        """
        self.n_data = n_data
        self.p_0 = p_0
        self.r = r
        self.l = l
        self.save_path = save_path
        self.s_list = s_list

        random.seed(0)

    
    def set_target_ranges(self, ux_min, ux_max, uy_min, uy_max, l_min, l_max):
        """
        Args:
            ux_min (float): minimum value of ux to be generated in data
            ux_max (float): maximum value of ux to be generated in data
            uy_min (float): minimum value of uy to be generated in data
            uy_max (float): maximum value of uy to be generated in data
            l_min (float): minimum value of l to be generated in data
            l_max (float): maximum value of l to be generated in data
        """
        self.ux_min = ux_min
        self.ux_max = ux_max
        self.uy_min = uy_min
        self.uy_max = uy_max
        self.l_min = l_min
        self.l_max = l_max


    def set_camera_params(self, fx, fy, cx, cy, size_x, size_y, camera_extrinsics):
        """
        Set intrinsic and extrinsic camera parameters

        Args:
            fx (float): horizontal direction focal length
            fy (float): vertical direction focal length
            cx (float): horizontal center of image
            cy (float): vertical center of image
            size_x (int): width of image
            size_y (int): height of image
            camera_extrinsics ((4, 4) numpy array): RT matrix 
        """
        self.fx = fx
        self.fy = fy
        self.cx = cx
        self.cy = cy
        self.size_x = size_x
        self.size_y = size_y
        self.camera_extrinsics = camera_extrinsics


    def check_view_boundary(self, ux_target, uy_target, l_target):
        """
        Check whether the given targets result in the end point of catheter falling outside of camera view
        
        Args:
            ux_target (float): 1st pair of tendon length (responsible for catheter bending)
            uy_target (float): 2nd pair of tendon length (responsible for catheter bending)
            l_target (float): length of bending portion of the catheter (responsible for insertion)

        Returns:
            (bool): whether the given targets result in the end point of catheter falling outside
                of camera view
        """
        for s in self.s_list:

            p_3d = transforms.cc_transform_3dof(self.p_0, ux_target, uy_target, l_target, self.r, s)
            p_2d = transforms.world_to_image_transform(p_3d, self.camera_extrinsics, self.fx, self.fy, self.cx, self.cy)

            p_2d[0] = round(self.size_x - p_2d[0])
            p_2d[1] = round(p_2d[1])

            margin = 10 # in pixels
            #if p_2d[0] >= self.size_x or p_2d[0] < 0 or p_2d[1] >= self.size_y or p_2d[1] < 0:  
            if p_2d[0] >= self.size_x - margin or p_2d[0] < margin or p_2d[1] >= self.size_y - margin or p_2d[1] < margin:                
                return False

        return True


    def generate_random_float(self, range_min, range_max):
        """
        Ouputs a random number within the given range
        """
        return random.random() * (range_max - range_min) + range_min


    def generate_data(self):
        """
        Generate a certain number of data within the specified parameter ranges and
            save the data in a given path 
        """
        self.generated_data = np.zeros((self.n_data, 3))

        n_iter = 0
        n_valid_data = 0

        while n_valid_data < self.n_data:

            print('n_iter = ', n_iter, ' n_valid_data = ', n_valid_data)

            ux_target = self.generate_random_float(self.ux_min, self.ux_max)
            uy_target = self.generate_random_float(self.uy_min, self.uy_max)
            l_target = self.generate_random_float(self.l_min, self.l_max)

            ## Boundary with the generated l_target and the initial l must both be checked to accomodate both 2-DOF and 3-DOF experiments
            if self.check_view_boundary(ux_target, uy_target, l_target) and self.check_view_boundary(ux_target, uy_target, self.l):
                self.generated_data[n_valid_data, :] = np.array([ux_target, uy_target, l_target])
                n_valid_data += 1

            n_iter += 1
        
        print('Generated ', n_valid_data, ' data in ', n_iter, ' iterations:')
        print(self.generated_data)

        np.save(self.save_path, self.generated_data)
        
    def visualize_targets(self, save_path, n_mid_points, n_iter):
        for i, targets in enumerate(self.generated_data):
            ux = targets[0]
            uy = targets[1]
            l = targets[2]
            
            catheter = CCCatheter(self.p_0, self.l, self.r, None, None, n_mid_points, n_iter, verbose=0)
            catheter.set_3dof_params(ux, uy, l)
            catheter.calculate_cc_points()
            catheter.calculate_beziers_control_points()
            
            name = f'target_{i}'
            curve_specs_path = os.path.join(save_path , name + '.npy')
            image_save_path = os.path.join(save_path, name + '.png')
            
            catheter.render_beziers(curve_specs_path, image_save_path)

# %%
### Universal parameters
p_0 = np.array([2e-2, 2e-3, 0])
r = 0.01
n_iter = 20
n_data = 10 # 100
noise_percentage = 0.25
ux_init = 0.00001
uy_init = 0.00001
l_init = 0.2


### Target parameter data generation
data_alias = 'D' + str(0).zfill(2)
data_save_path = os.path.join(path_settings.target_parameters_dir, data_alias + '.npy')
print(data_save_path)
s_list = [0.5, 1]

data_gen = DataGeneration(n_data, p_0, r, l_init, s_list, data_save_path)
data_gen.set_target_ranges(-0.005, 0.005, -0.005, 0.005, 0.1, 0.5)
data_gen.set_camera_params(camera_settings.a, camera_settings.b, camera_settings.center_x, camera_settings.center_y, camera_settings.image_size_x, camera_settings.image_size_y, camera_settings.extrinsics)
data_gen.generate_data()
target_parameters = np.load(data_save_path)
# Out:
# E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\D00.npy
# n_iter =  0  n_valid_data =  0
# n_iter =  1  n_valid_data =  0
# n_iter =  2  n_valid_data =  0
# n_iter =  3  n_valid_data =  0
# n_iter =  4  n_valid_data =  0
# n_iter =  5  n_valid_data =  0
# n_iter =  6  n_valid_data =  0
# n_iter =  7  n_valid_data =  0
# n_iter =  8  n_valid_data =  0
# n_iter =  9  n_valid_data =  0
# n_iter =  10  n_valid_data =  0
# n_iter =  11  n_valid_data =  0
# n_iter =  12  n_valid_data =  0
# n_iter =  13  n_valid_data =  0
# n_iter =  14  n_valid_data =  0
# n_iter =  15  n_valid_data =  0
# n_iter =  16  n_valid_data =  0
# n_iter =  17  n_valid_data =  0
# n_iter =  18  n_valid_data =  0
# n_iter =  19  n_valid_data =  0
# n_iter =  20  n_valid_data =  0
# n_iter =  21  n_valid_data =  0
# n_iter =  22  n_valid_data =  1
# n_iter =  23  n_valid_data =  1
# n_iter =  24  n_valid_data =  1
# n_iter =  25  n_valid_data =  1
# n_iter =  26  n_valid_data =  1
# n_iter =  27  n_valid_data =  1
# n_iter =  28  n_valid_data =  1
# n_iter =  29  n_valid_data =  1
# n_iter =  30  n_valid_data =  1
# n_iter =  31  n_valid_data =  1
# n_iter =  32  n_valid_data =  1
# n_iter =  33  n_valid_data =  1
# n_iter =  34  n_valid_data =  1
# n_iter =  35  n_valid_data =  1
# n_iter =  36  n_valid_data =  1
# n_iter =  37  n_valid_data =  1
# n_iter =  38  n_valid_data =  1
# n_iter =  39  n_valid_data =  1
# n_iter =  40  n_valid_data =  1
# n_iter =  41  n_valid_data =  1
# n_iter =  42  n_valid_data =  1
# n_iter =  43  n_valid_data =  1
# n_iter =  44  n_valid_data =  1
# n_iter =  45  n_valid_data =  1
# n_iter =  46  n_valid_data =  1
# n_iter =  47  n_valid_data =  1
# n_iter =  48  n_valid_data =  1
# n_iter =  49  n_valid_data =  1
# n_iter =  50  n_valid_data =  1
# n_iter =  51  n_valid_data =  1
# n_iter =  52  n_valid_data =  1
# n_iter =  53  n_valid_data =  1
# n_iter =  54  n_valid_data =  1
# n_iter =  55  n_valid_data =  2
# n_iter =  56  n_valid_data =  2
# n_iter =  57  n_valid_data =  2
# n_iter =  58  n_valid_data =  2
# n_iter =  59  n_valid_data =  2
# n_iter =  60  n_valid_data =  2
# n_iter =  61  n_valid_data =  2
# n_iter =  62  n_valid_data =  3
# n_iter =  63  n_valid_data =  3
# n_iter =  64  n_valid_data =  3
# n_iter =  65  n_valid_data =  3
# n_iter =  66  n_valid_data =  3
# n_iter =  67  n_valid_data =  3
# n_iter =  68  n_valid_data =  3
# n_iter =  69  n_valid_data =  4
# n_iter =  70  n_valid_data =  4
# n_iter =  71  n_valid_data =  4
# n_iter =  72  n_valid_data =  4
# n_iter =  73  n_valid_data =  4
# n_iter =  74  n_valid_data =  4
# n_iter =  75  n_valid_data =  4
# n_iter =  76  n_valid_data =  4
# n_iter =  77  n_valid_data =  4
# n_iter =  78  n_valid_data =  4
# n_iter =  79  n_valid_data =  4
# n_iter =  80  n_valid_data =  4
# n_iter =  81  n_valid_data =  4
# n_iter =  82  n_valid_data =  4
# n_iter =  83  n_valid_data =  4
# n_iter =  84  n_valid_data =  4
# n_iter =  85  n_valid_data =  4
# n_iter =  86  n_valid_data =  4
# n_iter =  87  n_valid_data =  4
# n_iter =  88  n_valid_data =  4
# n_iter =  89  n_valid_data =  4
# n_iter =  90  n_valid_data =  4
# n_iter =  91  n_valid_data =  4
# n_iter =  92  n_valid_data =  4
# n_iter =  93  n_valid_data =  4
# n_iter =  94  n_valid_data =  4
# n_iter =  95  n_valid_data =  4
# n_iter =  96  n_valid_data =  4
# n_iter =  97  n_valid_data =  4
# n_iter =  98  n_valid_data =  4
# n_iter =  99  n_valid_data =  4
# n_iter =  100  n_valid_data =  4
# n_iter =  101  n_valid_data =  4
# n_iter =  102  n_valid_data =  4
# n_iter =  103  n_valid_data =  4
# n_iter =  104  n_valid_data =  4
# n_iter =  105  n_valid_data =  5
# n_iter =  106  n_valid_data =  5
# n_iter =  107  n_valid_data =  5
# n_iter =  108  n_valid_data =  5
# n_iter =  109  n_valid_data =  5
# n_iter =  110  n_valid_data =  5
# n_iter =  111  n_valid_data =  5
# n_iter =  112  n_valid_data =  5
# n_iter =  113  n_valid_data =  5
# n_iter =  114  n_valid_data =  5
# n_iter =  115  n_valid_data =  5
# n_iter =  116  n_valid_data =  5
# n_iter =  117  n_valid_data =  5
# n_iter =  118  n_valid_data =  5
# n_iter =  119  n_valid_data =  5
# n_iter =  120  n_valid_data =  5
# n_iter =  121  n_valid_data =  5
# n_iter =  122  n_valid_data =  5
# n_iter =  123  n_valid_data =  5
# n_iter =  124  n_valid_data =  5
# n_iter =  125  n_valid_data =  5
# n_iter =  126  n_valid_data =  5
# n_iter =  127  n_valid_data =  5
# n_iter =  128  n_valid_data =  5
# n_iter =  129  n_valid_data =  5
# n_iter =  130  n_valid_data =  5
# n_iter =  131  n_valid_data =  5
# n_iter =  132  n_valid_data =  5
# n_iter =  133  n_valid_data =  5
# n_iter =  134  n_valid_data =  5
# n_iter =  135  n_valid_data =  5
# n_iter =  136  n_valid_data =  5
# n_iter =  137  n_valid_data =  5
# n_iter =  138  n_valid_data =  5
# n_iter =  139  n_valid_data =  5
# n_iter =  140  n_valid_data =  5
# n_iter =  141  n_valid_data =  5
# n_iter =  142  n_valid_data =  5
# n_iter =  143  n_valid_data =  5
# n_iter =  144  n_valid_data =  5
# n_iter =  145  n_valid_data =  5
# n_iter =  146  n_valid_data =  5
# n_iter =  147  n_valid_data =  5
# n_iter =  148  n_valid_data =  5
# n_iter =  149  n_valid_data =  5
# n_iter =  150  n_valid_data =  5
# n_iter =  151  n_valid_data =  5
# n_iter =  152  n_valid_data =  5
# n_iter =  153  n_valid_data =  5
# n_iter =  154  n_valid_data =  5
# n_iter =  155  n_valid_data =  5
# n_iter =  156  n_valid_data =  5
# n_iter =  157  n_valid_data =  5
# n_iter =  158  n_valid_data =  5
# n_iter =  159  n_valid_data =  5
# n_iter =  160  n_valid_data =  5
# n_iter =  161  n_valid_data =  5
# n_iter =  162  n_valid_data =  5
# n_iter =  163  n_valid_data =  5
# n_iter =  164  n_valid_data =  5
# n_iter =  165  n_valid_data =  5
# n_iter =  166  n_valid_data =  5
# n_iter =  167  n_valid_data =  5
# n_iter =  168  n_valid_data =  5
# n_iter =  169  n_valid_data =  5
# n_iter =  170  n_valid_data =  5
# n_iter =  171  n_valid_data =  5
# n_iter =  172  n_valid_data =  5
# n_iter =  173  n_valid_data =  5
# n_iter =  174  n_valid_data =  5
# n_iter =  175  n_valid_data =  5
# n_iter =  176  n_valid_data =  5
# n_iter =  177  n_valid_data =  5
# n_iter =  178  n_valid_data =  5
# n_iter =  179  n_valid_data =  5
# n_iter =  180  n_valid_data =  5
# n_iter =  181  n_valid_data =  5
# n_iter =  182  n_valid_data =  5
# n_iter =  183  n_valid_data =  5
# n_iter =  184  n_valid_data =  5
# n_iter =  185  n_valid_data =  5
# n_iter =  186  n_valid_data =  5
# n_iter =  187  n_valid_data =  6
# n_iter =  188  n_valid_data =  6
# n_iter =  189  n_valid_data =  6
# n_iter =  190  n_valid_data =  6
# n_iter =  191  n_valid_data =  6
# n_iter =  192  n_valid_data =  6
# n_iter =  193  n_valid_data =  6
# n_iter =  194  n_valid_data =  6
# n_iter =  195  n_valid_data =  6
# n_iter =  196  n_valid_data =  6
# n_iter =  197  n_valid_data =  6
# n_iter =  198  n_valid_data =  6
# n_iter =  199  n_valid_data =  6
# n_iter =  200  n_valid_data =  6
# n_iter =  201  n_valid_data =  6
# n_iter =  202  n_valid_data =  6
# n_iter =  203  n_valid_data =  6
# n_iter =  204  n_valid_data =  6
# n_iter =  205  n_valid_data =  6
# n_iter =  206  n_valid_data =  6
# n_iter =  207  n_valid_data =  6
# n_iter =  208  n_valid_data =  6
# n_iter =  209  n_valid_data =  6
# n_iter =  210  n_valid_data =  6
# n_iter =  211  n_valid_data =  6
# n_iter =  212  n_valid_data =  6
# n_iter =  213  n_valid_data =  6
# n_iter =  214  n_valid_data =  6
# n_iter =  215  n_valid_data =  7
# n_iter =  216  n_valid_data =  7
# n_iter =  217  n_valid_data =  7
# n_iter =  218  n_valid_data =  7
# n_iter =  219  n_valid_data =  7
# n_iter =  220  n_valid_data =  7
# n_iter =  221  n_valid_data =  7
# n_iter =  222  n_valid_data =  7
# n_iter =  223  n_valid_data =  7
# n_iter =  224  n_valid_data =  7
# n_iter =  225  n_valid_data =  7
# n_iter =  226  n_valid_data =  7
# n_iter =  227  n_valid_data =  7
# n_iter =  228  n_valid_data =  7
# n_iter =  229  n_valid_data =  7
# n_iter =  230  n_valid_data =  7
# n_iter =  231  n_valid_data =  7
# n_iter =  232  n_valid_data =  7
# n_iter =  233  n_valid_data =  7
# n_iter =  234  n_valid_data =  7
# n_iter =  235  n_valid_data =  7
# n_iter =  236  n_valid_data =  7
# n_iter =  237  n_valid_data =  7
# n_iter =  238  n_valid_data =  7
# n_iter =  239  n_valid_data =  7
# n_iter =  240  n_valid_data =  7
# n_iter =  241  n_valid_data =  7
# n_iter =  242  n_valid_data =  7
# n_iter =  243  n_valid_data =  7
# n_iter =  244  n_valid_data =  7
# n_iter =  245  n_valid_data =  7
# n_iter =  246  n_valid_data =  7
# n_iter =  247  n_valid_data =  7
# n_iter =  248  n_valid_data =  7
# n_iter =  249  n_valid_data =  7
# n_iter =  250  n_valid_data =  7
# n_iter =  251  n_valid_data =  7
# n_iter =  252  n_valid_data =  7
# n_iter =  253  n_valid_data =  7
# n_iter =  254  n_valid_data =  7
# n_iter =  255  n_valid_data =  7
# n_iter =  256  n_valid_data =  7
# n_iter =  257  n_valid_data =  7
# n_iter =  258  n_valid_data =  7
# n_iter =  259  n_valid_data =  7
# n_iter =  260  n_valid_data =  7
# n_iter =  261  n_valid_data =  8
# n_iter =  262  n_valid_data =  8
# n_iter =  263  n_valid_data =  8
# n_iter =  264  n_valid_data =  8
# n_iter =  265  n_valid_data =  8
# n_iter =  266  n_valid_data =  8
# n_iter =  267  n_valid_data =  8
# n_iter =  268  n_valid_data =  8
# n_iter =  269  n_valid_data =  8
# n_iter =  270  n_valid_data =  8
# n_iter =  271  n_valid_data =  8
# n_iter =  272  n_valid_data =  8
# n_iter =  273  n_valid_data =  8
# n_iter =  274  n_valid_data =  8
# n_iter =  275  n_valid_data =  8
# n_iter =  276  n_valid_data =  8
# n_iter =  277  n_valid_data =  8
# n_iter =  278  n_valid_data =  8
# n_iter =  279  n_valid_data =  8
# n_iter =  280  n_valid_data =  8
# n_iter =  281  n_valid_data =  8
# n_iter =  282  n_valid_data =  8
# n_iter =  283  n_valid_data =  8
# n_iter =  284  n_valid_data =  8
# n_iter =  285  n_valid_data =  8
# n_iter =  286  n_valid_data =  8
# n_iter =  287  n_valid_data =  8
# n_iter =  288  n_valid_data =  8
# n_iter =  289  n_valid_data =  8
# n_iter =  290  n_valid_data =  8
# n_iter =  291  n_valid_data =  8
# n_iter =  292  n_valid_data =  8
# n_iter =  293  n_valid_data =  8
# n_iter =  294  n_valid_data =  8
# n_iter =  295  n_valid_data =  8
# n_iter =  296  n_valid_data =  8
# n_iter =  297  n_valid_data =  8
# n_iter =  298  n_valid_data =  8
# n_iter =  299  n_valid_data =  8
# n_iter =  300  n_valid_data =  8
# n_iter =  301  n_valid_data =  8
# n_iter =  302  n_valid_data =  8
# n_iter =  303  n_valid_data =  8
# n_iter =  304  n_valid_data =  8
# n_iter =  305  n_valid_data =  8
# n_iter =  306  n_valid_data =  8
# n_iter =  307  n_valid_data =  8
# n_iter =  308  n_valid_data =  8
# n_iter =  309  n_valid_data =  8
# n_iter =  310  n_valid_data =  8
# n_iter =  311  n_valid_data =  8
# n_iter =  312  n_valid_data =  8
# n_iter =  313  n_valid_data =  8
# n_iter =  314  n_valid_data =  8
# n_iter =  315  n_valid_data =  8
# n_iter =  316  n_valid_data =  8
# n_iter =  317  n_valid_data =  8
# n_iter =  318  n_valid_data =  8
# n_iter =  319  n_valid_data =  8
# n_iter =  320  n_valid_data =  8
# n_iter =  321  n_valid_data =  8
# n_iter =  322  n_valid_data =  8
# n_iter =  323  n_valid_data =  8
# n_iter =  324  n_valid_data =  8
# n_iter =  325  n_valid_data =  8
# n_iter =  326  n_valid_data =  8
# n_iter =  327  n_valid_data =  8
# n_iter =  328  n_valid_data =  8
# n_iter =  329  n_valid_data =  8
# n_iter =  330  n_valid_data =  8
# n_iter =  331  n_valid_data =  8
# n_iter =  332  n_valid_data =  8
# n_iter =  333  n_valid_data =  8
# n_iter =  334  n_valid_data =  8
# n_iter =  335  n_valid_data =  8
# n_iter =  336  n_valid_data =  9
# n_iter =  337  n_valid_data =  9
# n_iter =  338  n_valid_data =  9
# n_iter =  339  n_valid_data =  9
# n_iter =  340  n_valid_data =  9
# n_iter =  341  n_valid_data =  9
# Generated  10  data in  342  iterations:
# [[ 1.03185628e-03  8.76170642e-04  2.77995611e-01]
#  [ 6.91127395e-04  8.60013006e-05  2.24578400e-01]
#  [-1.11982765e-03 -8.55820117e-04  3.60333145e-01]
#  [-1.27343989e-04  6.14049256e-04  4.02193907e-01]
#  [ 1.90037287e-04 -5.14557144e-04  2.95447522e-01]
#  [-9.13737788e-04 -8.27745202e-04  3.91272202e-01]
#  [-2.73344238e-04 -8.48925992e-04  2.90686099e-01]
#  [-6.51563174e-04  5.70540644e-04  2.14202316e-01]
#  [ 4.88772611e-04 -7.61207694e-04  4.79915219e-01]
#  [ 3.78704557e-04  5.45598516e-04  4.96036134e-01]]

# %%
print(target_parameters)
# Out:
# [[ 1.03185628e-03  8.76170642e-04  2.77995611e-01]
#  [ 6.91127395e-04  8.60013006e-05  2.24578400e-01]
#  [-1.11982765e-03 -8.55820117e-04  3.60333145e-01]
#  [-1.27343989e-04  6.14049256e-04  4.02193907e-01]
#  [ 1.90037287e-04 -5.14557144e-04  2.95447522e-01]
#  [-9.13737788e-04 -8.27745202e-04  3.91272202e-01]
#  [-2.73344238e-04 -8.48925992e-04  2.90686099e-01]
#  [-6.51563174e-04  5.70540644e-04  2.14202316e-01]
#  [ 4.88772611e-04 -7.61207694e-04  4.79915219e-01]
#  [ 3.78704557e-04  5.45598516e-04  4.96036134e-01]]

# %%
data_gen.visualize_targets(path_settings.target_parameters_dir, 1, n_iter)
# Out:
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_0.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_1.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_2.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_3.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_4.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_5.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_6.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_7.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_8.png
# Image rendered. Image saved to E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/data/target_parameters\target_9.png
