# %%
import sympy as sp
from sympy.printing.pycode import pycode

# %%
# Define symbols
ux, uy, l, r, s = sp.symbols('ux uy l r s')
u = sp.sqrt(ux**2 + uy**2)
k = u / (l * r)

# Define T matrix
T = sp.Matrix([
    [1 + (ux**2) / (u**2) * (sp.cos(k * s) - 1), ux * uy / (u**2) * (sp.cos(k * s) - 1),                   -ux / u * sp.sin(k * s), -r * l * ux * (1 - sp.cos(k * s)) / (u**2)],
    [ux * uy / (u**2) * (sp.cos(k * s) - 1),       sp.cos(k * s) + (ux**2) / (u**2) * (1 - sp.cos(k * s)), -uy / u * sp.sin(k * s), -r * l * uy * (1 - sp.cos(k * s)) / (u**2)],
    [ux / u * sp.sin(k * s),                         uy / u * sp.sin(k * s),                               sp.cos(k * s),           r * l * sp.sin(k * s) / u                  ],
    [0,                                              0,                                                    0,                       1                                          ]
])

# Calculate the derivative of T with respect to ux
dT_dux = T.diff(ux)
sp.pprint(dT_dux)

path = 'E:/OneDrive - UC San Diego/UCSD/Lab/Catheter/diff_catheter/scripts/derivation/'
name = 'dT_dux.py'
filename = path + name

# Convert the result to python code
dT_dux_pycode = pycode(dT_dux)

# # Write the python code to a file
# with open(filename, "w") as f:
#     f.write(dT_dux_pycode)
# Out:
# ⎡          ⎛   ⎛     ___________⎞    ⎞        ⎛   ⎛     ___________⎞    ⎞
# ⎢          ⎜   ⎜    ╱   2     2 ⎟    ⎟        ⎜   ⎜    ╱   2     2 ⎟    ⎟
# ⎢        3 ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟        ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟
# ⎢    2⋅ux ⋅⎜cos⎜────────────────⎟ - 1⎟   2⋅ux⋅⎜cos⎜────────────────⎟ - 1⎟   s⋅
# ⎢          ⎝   ⎝      l⋅r       ⎠    ⎠        ⎝   ⎝      l⋅r       ⎠    ⎠
# ⎢  - ───────────────────────────────── + ──────────────────────────────── - ──
# ⎢                          2                          2     2
# ⎢               ⎛  2     2⎞                         ux  + uy
# ⎢               ⎝ux  + uy ⎠
# ⎢
# ⎢           ⎛   ⎛     ___________⎞    ⎞      ⎛   ⎛     ___________⎞    ⎞
# ⎢           ⎜   ⎜    ╱   2     2 ⎟    ⎟      ⎜   ⎜    ╱   2     2 ⎟    ⎟
# ⎢      2    ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟      ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟
# ⎢  2⋅ux ⋅uy⋅⎜cos⎜────────────────⎟ - 1⎟   uy⋅⎜cos⎜────────────────⎟ - 1⎟   s⋅u
# ⎢           ⎝   ⎝      l⋅r       ⎠    ⎠      ⎝   ⎝      l⋅r       ⎠    ⎠
# ⎢- ──────────────────────────────────── + ────────────────────────────── - ───
# ⎢                         2                           2     2
# ⎢              ⎛  2     2⎞                          ux  + uy
# ⎢              ⎝ux  + uy ⎠
# ⎢
# ⎢                    ⎛     ___________⎞      ⎛     ___________⎞            ⎛
# ⎢                    ⎜    ╱   2     2 ⎟      ⎜    ╱   2     2 ⎟            ⎜
# ⎢               2    ⎜s⋅╲╱  ux  + uy  ⎟      ⎜s⋅╲╱  ux  + uy  ⎟       2    ⎜s⋅
# ⎢             ux ⋅sin⎜────────────────⎟   sin⎜────────────────⎟   s⋅ux ⋅cos⎜──
# ⎢                    ⎝      l⋅r       ⎠      ⎝      l⋅r       ⎠            ⎝
# ⎢           - ───────────────────────── + ───────────────────── + ────────────
# ⎢                              3/2               ___________                ⎛
# ⎢                   ⎛  2     2⎞                 ╱   2     2             l⋅r⋅⎝u
# ⎢                   ⎝ux  + uy ⎠               ╲╱  ux  + uy
# ⎢
# ⎣                                                   0
#
#        ⎛     ___________⎞                           ⎛   ⎛     ___________⎞
#        ⎜    ╱   2     2 ⎟                           ⎜   ⎜    ╱   2     2 ⎟
#   3    ⎜s⋅╲╱  ux  + uy  ⎟                      2    ⎜   ⎜s⋅╲╱  ux  + uy  ⎟
# ux ⋅sin⎜────────────────⎟                  2⋅ux ⋅uy⋅⎜cos⎜────────────────⎟ - 1
#        ⎝      l⋅r       ⎠                           ⎝   ⎝      l⋅r       ⎠
# ─────────────────────────                - ───────────────────────────────────
#                   3/2                                             2
#        ⎛  2     2⎞                                     ⎛  2     2⎞
#    l⋅r⋅⎝ux  + uy ⎠                                     ⎝ux  + uy ⎠
#
#          ⎛     ___________⎞          ⎛       ⎛     ___________⎞⎞        ⎛
#          ⎜    ╱   2     2 ⎟          ⎜       ⎜    ╱   2     2 ⎟⎟        ⎜
#  2       ⎜s⋅╲╱  ux  + uy  ⎟        3 ⎜       ⎜s⋅╲╱  ux  + uy  ⎟⎟        ⎜
# x ⋅uy⋅sin⎜────────────────⎟    2⋅ux ⋅⎜1 - cos⎜────────────────⎟⎟   2⋅ux⋅⎜1 - c
#          ⎝      l⋅r       ⎠          ⎝       ⎝      l⋅r       ⎠⎠        ⎝
# ───────────────────────────  - ───────────────────────────────── + ───────────
#                   3/2                                2
#        ⎛  2     2⎞                        ⎛  2     2⎞
#    l⋅r⋅⎝ux  + uy ⎠                        ⎝ux  + uy ⎠
#
#    ___________⎞                                                           ⎛
#   ╱   2     2 ⎟                                                           ⎜
# ╲╱  ux  + uy  ⎟                                                           ⎜s⋅╲
# ──────────────⎟                                                  ux⋅uy⋅sin⎜───
#     l⋅r       ⎠                                                           ⎝
# ───────────────                                                - ─────────────
#  2     2⎞
# x  + uy ⎠                                                               ⎛  2
#                                                                         ⎝ux  +
#
#
#
# ⎞      ⎛   ⎛     ___________⎞    ⎞               ⎛     ___________⎞
# ⎟      ⎜   ⎜    ╱   2     2 ⎟    ⎟               ⎜    ╱   2     2 ⎟
# ⎟      ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟       2       ⎜s⋅╲╱  ux  + uy  ⎟
# ⎟   uy⋅⎜cos⎜────────────────⎟ - 1⎟   s⋅ux ⋅uy⋅sin⎜────────────────⎟
# ⎠      ⎝   ⎝      l⋅r       ⎠    ⎠               ⎝      l⋅r       ⎠
# ─ + ────────────────────────────── - ──────────────────────────────
#                 2     2                                   3/2
#               ux  + uy                         ⎛  2     2⎞
#                                            l⋅r⋅⎝ux  + uy ⎠
#
#   ⎛     ___________⎞⎞            ⎛     ___________⎞           ⎛     __________
#   ⎜    ╱   2     2 ⎟⎟            ⎜    ╱   2     2 ⎟           ⎜    ╱   2     2
#   ⎜s⋅╲╱  ux  + uy  ⎟⎟       3    ⎜s⋅╲╱  ux  + uy  ⎟           ⎜s⋅╲╱  ux  + uy
# os⎜────────────────⎟⎟   s⋅ux ⋅sin⎜────────────────⎟   s⋅ux⋅sin⎜───────────────
#   ⎝      l⋅r       ⎠⎠            ⎝      l⋅r       ⎠           ⎝      l⋅r
# ───────────────────── + ─────────────────────────── - ────────────────────────
#   2     2                                   3/2                  ___________
# ux  + uy                         ⎛  2     2⎞                    ╱   2     2
#                              l⋅r⋅⎝ux  + uy ⎠              l⋅r⋅╲╱  ux  + uy
#
#   ___________⎞              ⎛     ___________⎞
#  ╱   2     2 ⎟              ⎜    ╱   2     2 ⎟
# ╱  ux  + uy  ⎟              ⎜s⋅╲╱  ux  + uy  ⎟
# ─────────────⎟   s⋅ux⋅uy⋅cos⎜────────────────⎟
#    l⋅r       ⎠              ⎝      l⋅r       ⎠
# ────────────── + ─────────────────────────────
#      3/2                    ⎛  2     2⎞
#    2⎞                   l⋅r⋅⎝ux  + uy ⎠
#  uy ⎠
#
#                0
#
#            ⎛     ___________⎞      ⎛     ___________⎞            ⎛     _______
#            ⎜    ╱   2     2 ⎟      ⎜    ╱   2     2 ⎟            ⎜    ╱   2
#       2    ⎜s⋅╲╱  ux  + uy  ⎟      ⎜s⋅╲╱  ux  + uy  ⎟       2    ⎜s⋅╲╱  ux  +
#     ux ⋅sin⎜────────────────⎟   sin⎜────────────────⎟   s⋅ux ⋅cos⎜────────────
#            ⎝      l⋅r       ⎠      ⎝      l⋅r       ⎠            ⎝      l⋅r
#     ───────────────────────── - ───────────────────── - ──────────────────────
#                      3/2               ___________                ⎛  2     2⎞
#           ⎛  2     2⎞                 ╱   2     2             l⋅r⋅⎝ux  + uy ⎠
#           ⎝ux  + uy ⎠               ╲╱  ux  + uy
#
# _⎞                     ⎛     ___________⎞              ⎛     ___________⎞
#  ⎟                     ⎜    ╱   2     2 ⎟              ⎜    ╱   2     2 ⎟
#  ⎟                     ⎜s⋅╲╱  ux  + uy  ⎟              ⎜s⋅╲╱  ux  + uy  ⎟
# ─⎟            ux⋅uy⋅sin⎜────────────────⎟   s⋅ux⋅uy⋅cos⎜────────────────⎟
#  ⎠                     ⎝      l⋅r       ⎠              ⎝      l⋅r       ⎠
# ──            ─────────────────────────── - ─────────────────────────────
#                                 3/2                    ⎛  2     2⎞
#                      ⎛  2     2⎞                   l⋅r⋅⎝ux  + uy ⎠
#                      ⎝ux  + uy ⎠
#
#                                       ⎛     ___________⎞
#                                       ⎜    ╱   2     2 ⎟
#                                       ⎜s⋅╲╱  ux  + uy  ⎟
#                              -s⋅ux⋅sin⎜────────────────⎟
#                                       ⎝      l⋅r       ⎠
#                              ────────────────────────────
#                                          ___________
#                                         ╱   2     2
#                                   l⋅r⋅╲╱  ux  + uy
#
#                                            0
#
# ____⎞            ⎛       ⎛     ___________⎞⎞       ⎛       ⎛     ___________⎞⎞
#   2 ⎟            ⎜       ⎜    ╱   2     2 ⎟⎟       ⎜       ⎜    ╱   2     2 ⎟⎟
# uy  ⎟          2 ⎜       ⎜s⋅╲╱  ux  + uy  ⎟⎟       ⎜       ⎜s⋅╲╱  ux  + uy  ⎟⎟
# ────⎟  2⋅l⋅r⋅ux ⋅⎜1 - cos⎜────────────────⎟⎟   l⋅r⋅⎜1 - cos⎜────────────────⎟⎟
#     ⎠            ⎝       ⎝      l⋅r       ⎠⎠       ⎝       ⎝      l⋅r       ⎠⎠
# ─────  ───────────────────────────────────── - ───────────────────────────────
#                                2                            2     2
#                     ⎛  2     2⎞                           ux  + uy
#                     ⎝ux  + uy ⎠
#
#                                   ⎛       ⎛     ___________⎞⎞              ⎛
#                                   ⎜       ⎜    ╱   2     2 ⎟⎟              ⎜
#                                   ⎜       ⎜s⋅╲╱  ux  + uy  ⎟⎟              ⎜s⋅
#                       2⋅l⋅r⋅ux⋅uy⋅⎜1 - cos⎜────────────────⎟⎟   s⋅ux⋅uy⋅sin⎜──
#                                   ⎝       ⎝      l⋅r       ⎠⎠              ⎝
#                       ─────────────────────────────────────── - ──────────────
#                                                2
#                                     ⎛  2     2⎞                         ⎛  2
#                                     ⎝ux  + uy ⎠                         ⎝ux  +
#
#                                         ⎛     ___________⎞           ⎛     ___
#                                         ⎜    ╱   2     2 ⎟           ⎜    ╱
#                                         ⎜s⋅╲╱  ux  + uy  ⎟           ⎜s⋅╲╱  ux
#                               l⋅r⋅ux⋅sin⎜────────────────⎟   s⋅ux⋅cos⎜────────
#                                         ⎝      l⋅r       ⎠           ⎝      l⋅
#                             - ──────────────────────────── + ─────────────────
#                                                 3/2                    2     2
#                                      ⎛  2     2⎞                     ux  + uy
#                                      ⎝ux  + uy ⎠
#
#                                                          0
#
#             ⎛     ___________⎞⎤
#             ⎜    ╱   2     2 ⎟⎥
#        2    ⎜s⋅╲╱  ux  + uy  ⎟⎥
#    s⋅ux ⋅sin⎜────────────────⎟⎥
#             ⎝      l⋅r       ⎠⎥
#  - ───────────────────────────⎥
#                      3/2      ⎥
#           ⎛  2     2⎞         ⎥
#           ⎝ux  + uy ⎠         ⎥
#                               ⎥
#    ___________⎞               ⎥
#   ╱   2     2 ⎟               ⎥
# ╲╱  ux  + uy  ⎟               ⎥
# ──────────────⎟               ⎥
#     l⋅r       ⎠               ⎥
# ───────────────               ⎥
#      3/2                      ⎥
#    2⎞                         ⎥
#  uy ⎠                         ⎥
#                               ⎥
# ________⎞                     ⎥
# 2     2 ⎟                     ⎥
#   + uy  ⎟                     ⎥
# ────────⎟                     ⎥
# r       ⎠                     ⎥
# ─────────                     ⎥
#                               ⎥
#                               ⎥
#                               ⎥
#                               ⎥
#                               ⎦

# %%
dT_duy = T.diff(uy)
sp.pprint(dT_duy)

name = 'dT_duy.py'
filename = path + name
dT_duy_pycode = pycode(dT_duy)

# with open(filename, "w") as f:
#     f.write(dT_duy_pycode)
# Out:
# ⎡                           ⎛   ⎛     ___________⎞    ⎞               ⎛     __
# ⎢                           ⎜   ⎜    ╱   2     2 ⎟    ⎟               ⎜    ╱
# ⎢                      2    ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟       2       ⎜s⋅╲╱  u
# ⎢                  2⋅ux ⋅uy⋅⎜cos⎜────────────────⎟ - 1⎟   s⋅ux ⋅uy⋅sin⎜───────
# ⎢                           ⎝   ⎝      l⋅r       ⎠    ⎠               ⎝      l
# ⎢                - ──────────────────────────────────── - ────────────────────
# ⎢                                         2
# ⎢                              ⎛  2     2⎞                          ⎛  2     2
# ⎢                              ⎝ux  + uy ⎠                      l⋅r⋅⎝ux  + uy
# ⎢
# ⎢           ⎛   ⎛     ___________⎞    ⎞      ⎛   ⎛     ___________⎞    ⎞
# ⎢           ⎜   ⎜    ╱   2     2 ⎟    ⎟      ⎜   ⎜    ╱   2     2 ⎟    ⎟
# ⎢         2 ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟      ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟
# ⎢  2⋅ux⋅uy ⋅⎜cos⎜────────────────⎟ - 1⎟   ux⋅⎜cos⎜────────────────⎟ - 1⎟   s⋅u
# ⎢           ⎝   ⎝      l⋅r       ⎠    ⎠      ⎝   ⎝      l⋅r       ⎠    ⎠
# ⎢- ──────────────────────────────────── + ────────────────────────────── - ───
# ⎢                         2                           2     2
# ⎢              ⎛  2     2⎞                          ux  + uy
# ⎢              ⎝ux  + uy ⎠
# ⎢
# ⎢                                ⎛     ___________⎞              ⎛     _______
# ⎢                                ⎜    ╱   2     2 ⎟              ⎜    ╱   2
# ⎢                                ⎜s⋅╲╱  ux  + uy  ⎟              ⎜s⋅╲╱  ux  +
# ⎢                       ux⋅uy⋅sin⎜────────────────⎟   s⋅ux⋅uy⋅cos⎜────────────
# ⎢                                ⎝      l⋅r       ⎠              ⎝      l⋅r
# ⎢                     - ─────────────────────────── + ────────────────────────
# ⎢                                         3/2                    ⎛  2     2⎞
# ⎢                              ⎛  2     2⎞                   l⋅r⋅⎝ux  + uy ⎠
# ⎢                              ⎝ux  + uy ⎠
# ⎢
# ⎣                                                   0
#
# _________⎞                              ⎛   ⎛     ___________⎞    ⎞      ⎛   ⎛
#  2     2 ⎟                              ⎜   ⎜    ╱   2     2 ⎟    ⎟      ⎜   ⎜
# x  + uy  ⎟                            2 ⎜   ⎜s⋅╲╱  ux  + uy  ⎟    ⎟      ⎜   ⎜
# ─────────⎟                     2⋅ux⋅uy ⋅⎜cos⎜────────────────⎟ - 1⎟   ux⋅⎜cos⎜
# ⋅r       ⎠                              ⎝   ⎝      l⋅r       ⎠    ⎠      ⎝   ⎝
# ──────────                   - ──────────────────────────────────── + ────────
#  3/2                                                  2
# ⎞                                          ⎛  2     2⎞
# ⎠                                          ⎝ux  + uy ⎠
#
#          ⎛     ___________⎞               ⎛       ⎛     ___________⎞⎞
#          ⎜    ╱   2     2 ⎟               ⎜       ⎜    ╱   2     2 ⎟⎟
#     2    ⎜s⋅╲╱  ux  + uy  ⎟          2    ⎜       ⎜s⋅╲╱  ux  + uy  ⎟⎟       2
# x⋅uy ⋅sin⎜────────────────⎟      2⋅ux ⋅uy⋅⎜1 - cos⎜────────────────⎟⎟   s⋅ux ⋅
#          ⎝      l⋅r       ⎠               ⎝       ⎝      l⋅r       ⎠⎠
# ───────────────────────────    - ──────────────────────────────────── + ──────
#                   3/2                                   2
#        ⎛  2     2⎞                           ⎛  2     2⎞
#    l⋅r⋅⎝ux  + uy ⎠                           ⎝ux  + uy ⎠
#
# ____⎞                                            ⎛     ___________⎞      ⎛
#   2 ⎟                                            ⎜    ╱   2     2 ⎟      ⎜
# uy  ⎟                                       2    ⎜s⋅╲╱  ux  + uy  ⎟      ⎜s⋅╲╱
# ────⎟                                     uy ⋅sin⎜────────────────⎟   sin⎜────
#     ⎠                                            ⎝      l⋅r       ⎠      ⎝
# ─────                                   - ───────────────────────── + ────────
#                                                            3/2               _
#                                                 ⎛  2     2⎞                 ╱
#                                                 ⎝ux  + uy ⎠               ╲╱
#
#
#
#      ___________⎞    ⎞               ⎛     ___________⎞                     ⎛
#     ╱   2     2 ⎟    ⎟               ⎜    ╱   2     2 ⎟                     ⎜
# s⋅╲╱  ux  + uy  ⎟    ⎟          2    ⎜s⋅╲╱  ux  + uy  ⎟                     ⎜s
# ────────────────⎟ - 1⎟   s⋅ux⋅uy ⋅sin⎜────────────────⎟            ux⋅uy⋅sin⎜─
#       l⋅r       ⎠    ⎠               ⎝      l⋅r       ⎠                     ⎝
# ────────────────────── - ──────────────────────────────            ───────────
#     2     2                                   3/2
#   ux  + uy                         ⎛  2     2⎞                            ⎛  2
#                                l⋅r⋅⎝ux  + uy ⎠                            ⎝ux
#
#       ⎛     ___________⎞           ⎛     ___________⎞           ⎛     ________
#       ⎜    ╱   2     2 ⎟           ⎜    ╱   2     2 ⎟           ⎜    ╱   2
#       ⎜s⋅╲╱  ux  + uy  ⎟           ⎜s⋅╲╱  ux  + uy  ⎟      2    ⎜s⋅╲╱  ux  + u
# uy⋅sin⎜────────────────⎟   s⋅uy⋅sin⎜────────────────⎟    uy ⋅sin⎜─────────────
#       ⎝      l⋅r       ⎠           ⎝      l⋅r       ⎠           ⎝      l⋅r
# ──────────────────────── - ──────────────────────────    ─────────────────────
#                3/2                    ___________                         3/2
#     ⎛  2     2⎞                      ╱   2     2               ⎛  2     2⎞
# l⋅r⋅⎝ux  + uy ⎠                l⋅r⋅╲╱  ux  + uy                ⎝ux  + uy ⎠
#
#  ___________⎞            ⎛     ___________⎞
# ╱   2     2 ⎟            ⎜    ╱   2     2 ⎟
#   ux  + uy  ⎟       2    ⎜s⋅╲╱  ux  + uy  ⎟
# ────────────⎟   s⋅uy ⋅cos⎜────────────────⎟
#   l⋅r       ⎠            ⎝      l⋅r       ⎠
# ───────────── + ───────────────────────────
# __________                ⎛  2     2⎞
#   2     2             l⋅r⋅⎝ux  + uy ⎠
# ux  + uy
#
#   0
#
#     ___________⎞              ⎛     ___________⎞
#    ╱   2     2 ⎟              ⎜    ╱   2     2 ⎟
# ⋅╲╱  ux  + uy  ⎟              ⎜s⋅╲╱  ux  + uy  ⎟
# ───────────────⎟   s⋅ux⋅uy⋅cos⎜────────────────⎟                           2⋅l
#      l⋅r       ⎠              ⎝      l⋅r       ⎠
# ──────────────── - ─────────────────────────────                           ───
#        3/2                    ⎛  2     2⎞
#      2⎞                   l⋅r⋅⎝ux  + uy ⎠
#  + uy ⎠
#
# ___⎞      ⎛     ___________⎞            ⎛     ___________⎞            ⎛
#  2 ⎟      ⎜    ╱   2     2 ⎟            ⎜    ╱   2     2 ⎟            ⎜
# y  ⎟      ⎜s⋅╲╱  ux  + uy  ⎟       2    ⎜s⋅╲╱  ux  + uy  ⎟          2 ⎜
# ───⎟   sin⎜────────────────⎟   s⋅uy ⋅cos⎜────────────────⎟  2⋅l⋅r⋅uy ⋅⎜1 - cos
#    ⎠      ⎝      l⋅r       ⎠            ⎝      l⋅r       ⎠            ⎝
# ──── - ───────────────────── - ───────────────────────────  ──────────────────
#               ___________                ⎛  2     2⎞
#              ╱   2     2             l⋅r⋅⎝ux  + uy ⎠                     ⎛  2
#            ╲╱  ux  + uy                                                  ⎝ux
#
#              ⎛     ___________⎞
#              ⎜    ╱   2     2 ⎟
#              ⎜s⋅╲╱  ux  + uy  ⎟
#     -s⋅uy⋅sin⎜────────────────⎟
#              ⎝      l⋅r       ⎠
#     ────────────────────────────
#                 ___________
#                ╱   2     2
#          l⋅r⋅╲╱  ux  + uy
#
#                   0
#
#          ⎛       ⎛     ___________⎞⎞              ⎛     ___________⎞
#          ⎜       ⎜    ╱   2     2 ⎟⎟              ⎜    ╱   2     2 ⎟
#          ⎜       ⎜s⋅╲╱  ux  + uy  ⎟⎟              ⎜s⋅╲╱  ux  + uy  ⎟
# ⋅r⋅ux⋅uy⋅⎜1 - cos⎜────────────────⎟⎟   s⋅ux⋅uy⋅sin⎜────────────────⎟
#          ⎝       ⎝      l⋅r       ⎠⎠              ⎝      l⋅r       ⎠
# ──────────────────────────────────── - ─────────────────────────────
#                       2                                   3/2
#            ⎛  2     2⎞                         ⎛  2     2⎞
#            ⎝ux  + uy ⎠                         ⎝ux  + uy ⎠
#
# ⎛     ___________⎞⎞       ⎛       ⎛     ___________⎞⎞            ⎛     _______
# ⎜    ╱   2     2 ⎟⎟       ⎜       ⎜    ╱   2     2 ⎟⎟            ⎜    ╱   2
# ⎜s⋅╲╱  ux  + uy  ⎟⎟       ⎜       ⎜s⋅╲╱  ux  + uy  ⎟⎟       2    ⎜s⋅╲╱  ux  +
# ⎜────────────────⎟⎟   l⋅r⋅⎜1 - cos⎜────────────────⎟⎟   s⋅uy ⋅sin⎜────────────
# ⎝      l⋅r       ⎠⎠       ⎝       ⎝      l⋅r       ⎠⎠            ⎝      l⋅r
# ─────────────────── - ─────────────────────────────── - ──────────────────────
#       2                            2     2                                3/2
#     2⎞                           ux  + uy                      ⎛  2     2⎞
# + uy ⎠                                                         ⎝ux  + uy ⎠
#
#                ⎛     ___________⎞           ⎛     ___________⎞
#                ⎜    ╱   2     2 ⎟           ⎜    ╱   2     2 ⎟
#                ⎜s⋅╲╱  ux  + uy  ⎟           ⎜s⋅╲╱  ux  + uy  ⎟
#      l⋅r⋅uy⋅sin⎜────────────────⎟   s⋅uy⋅cos⎜────────────────⎟
#                ⎝      l⋅r       ⎠           ⎝      l⋅r       ⎠
#    - ──────────────────────────── + ──────────────────────────
#                        3/2                    2     2
#             ⎛  2     2⎞                     ux  + uy
#             ⎝ux  + uy ⎠
#
#                                 0
#
#      ⎤
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
# ____⎞⎥
#   2 ⎟⎥
# uy  ⎟⎥
# ────⎟⎥
#     ⎠⎥
# ─────⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎦

# %%
dT_dl = T.diff(l)
sp.pprint(dT_dl)

name = 'dT_dl.py'
filename = path + name
dT_dl_pycode = pycode(dT_dl)

with open(filename, "w") as f:
    f.write(dT_dl_pycode)
# Out:
# ⎡          ⎛     ___________⎞                                  ⎛     _________
# ⎢          ⎜    ╱   2     2 ⎟                                  ⎜    ╱   2
# ⎢     2    ⎜s⋅╲╱  ux  + uy  ⎟                                  ⎜s⋅╲╱  ux  + uy
# ⎢ s⋅ux ⋅sin⎜────────────────⎟                       s⋅ux⋅uy⋅sin⎜──────────────
# ⎢          ⎝      l⋅r       ⎠                                  ⎝      l⋅r
# ⎢ ───────────────────────────                       ──────────────────────────
# ⎢             ___________                                        ___________
# ⎢      2     ╱   2     2                                  2     ╱   2     2
# ⎢     l ⋅r⋅╲╱  ux  + uy                                  l ⋅r⋅╲╱  ux  + uy
# ⎢
# ⎢           ⎛     ___________⎞             ⎛     ___________⎞
# ⎢           ⎜    ╱   2     2 ⎟             ⎜    ╱   2     2 ⎟        _________
# ⎢           ⎜s⋅╲╱  ux  + uy  ⎟        2    ⎜s⋅╲╱  ux  + uy  ⎟       ╱   2
# ⎢s⋅ux⋅uy⋅sin⎜────────────────⎟    s⋅ux ⋅sin⎜────────────────⎟   s⋅╲╱  ux  + uy
# ⎢           ⎝      l⋅r       ⎠             ⎝      l⋅r       ⎠
# ⎢─────────────────────────────  - ─────────────────────────── + ──────────────
# ⎢             ___________                     ___________
# ⎢      2     ╱   2     2               2     ╱   2     2
# ⎢     l ⋅r⋅╲╱  ux  + uy               l ⋅r⋅╲╱  ux  + uy
# ⎢
# ⎢         ⎛     ___________⎞                                  ⎛     __________
# ⎢         ⎜    ╱   2     2 ⎟                                  ⎜    ╱   2     2
# ⎢         ⎜s⋅╲╱  ux  + uy  ⎟                                  ⎜s⋅╲╱  ux  + uy
# ⎢-s⋅ux⋅cos⎜────────────────⎟                         -s⋅uy⋅cos⎜───────────────
# ⎢         ⎝      l⋅r       ⎠                                  ⎝      l⋅r
# ⎢────────────────────────────                        ─────────────────────────
# ⎢             2                                                   2
# ⎢            l ⋅r                                                l ⋅r
# ⎢
# ⎢
# ⎣              0                                                  0
#
# __⎞                                     ⎛     ___________⎞               ⎛
# 2 ⎟                                     ⎜    ╱   2     2 ⎟               ⎜
#   ⎟                                     ⎜s⋅╲╱  ux  + uy  ⎟               ⎜
# ──⎟                             s⋅ux⋅cos⎜────────────────⎟          r⋅ux⋅⎜1 -
#   ⎠                                     ⎝      l⋅r       ⎠               ⎝
# ───                             ──────────────────────────        - ──────────
#                                             2
#                                            l ⋅r
#
#
#       ⎛     ___________⎞                ⎛     ___________⎞               ⎛
# __    ⎜    ╱   2     2 ⎟                ⎜    ╱   2     2 ⎟               ⎜
# 2     ⎜s⋅╲╱  ux  + uy  ⎟                ⎜s⋅╲╱  ux  + uy  ⎟               ⎜
#   ⋅sin⎜────────────────⎟        s⋅uy⋅cos⎜────────────────⎟          r⋅uy⋅⎜1 -
#       ⎝      l⋅r       ⎠                ⎝      l⋅r       ⎠               ⎝
# ────────────────────────        ──────────────────────────        - ──────────
#     2                                       2
#    l ⋅r                                    l ⋅r
#
#
# _⎞                                            ⎛     ___________⎞
#  ⎟                             ___________    ⎜    ╱   2     2 ⎟
#  ⎟                            ╱   2     2     ⎜s⋅╲╱  ux  + uy  ⎟
# ─⎟                        s⋅╲╱  ux  + uy  ⋅sin⎜────────────────⎟         r⋅sin
#  ⎠                                            ⎝      l⋅r       ⎠
# ───                       ──────────────────────────────────────         ─────
#                                             2
#                                            l ⋅r
#
#
#                                             0
#
#    ⎛     ___________⎞⎞           ⎛     ___________⎞⎤
#    ⎜    ╱   2     2 ⎟⎟           ⎜    ╱   2     2 ⎟⎥
#    ⎜s⋅╲╱  ux  + uy  ⎟⎟           ⎜s⋅╲╱  ux  + uy  ⎟⎥
# cos⎜────────────────⎟⎟   s⋅ux⋅sin⎜────────────────⎟⎥
#    ⎝      l⋅r       ⎠⎠           ⎝      l⋅r       ⎠⎥
# ────────────────────── + ──────────────────────────⎥
#    2     2                         ___________     ⎥
#  ux  + uy                         ╱   2     2      ⎥
#                               l⋅╲╱  ux  + uy       ⎥
#                                                    ⎥
#    ⎛     ___________⎞⎞           ⎛     ___________⎞⎥
#    ⎜    ╱   2     2 ⎟⎟           ⎜    ╱   2     2 ⎟⎥
#    ⎜s⋅╲╱  ux  + uy  ⎟⎟           ⎜s⋅╲╱  ux  + uy  ⎟⎥
# cos⎜────────────────⎟⎟   s⋅uy⋅sin⎜────────────────⎟⎥
#    ⎝      l⋅r       ⎠⎠           ⎝      l⋅r       ⎠⎥
# ────────────────────── + ──────────────────────────⎥
#    2     2                         ___________     ⎥
#  ux  + uy                         ╱   2     2      ⎥
#                               l⋅╲╱  ux  + uy       ⎥
#                                                    ⎥
# ⎛     ___________⎞        ⎛     ___________⎞       ⎥
# ⎜    ╱   2     2 ⎟        ⎜    ╱   2     2 ⎟       ⎥
# ⎜s⋅╲╱  ux  + uy  ⎟        ⎜s⋅╲╱  ux  + uy  ⎟       ⎥
# ⎜────────────────⎟   s⋅cos⎜────────────────⎟       ⎥
# ⎝      l⋅r       ⎠        ⎝      l⋅r       ⎠       ⎥
# ────────────────── - ───────────────────────       ⎥
#    ___________                  l                  ⎥
#   ╱   2     2                                      ⎥
# ╲╱  ux  + uy                                       ⎥
#                                                    ⎥
#                    0                               ⎦
